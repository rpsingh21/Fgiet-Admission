# %%
import numpy as np
import pandas as pd

# %%
csv = pd.read_html("http://localhost:8000/account/")

# %%
csv.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-2ec0ec31e36d> in <module>()
# ----> 1 csv.head()
#
# AttributeError: 'list' object has no attribute 'head'
